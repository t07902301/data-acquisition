# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # proxy vs baseline

# %%
core_session= {
    'WEDE': [4.991,7.145,8.545,9.345,10.082,10.782],
    'confidence':  [2.782,4.809,6.309,7.482,8.291,8.755],
    'random': [-6.518,-3.509,-0.527,2.136,4.345,5.791]
}

core_object= {
    'WEDE' : [5.736,6.173,7.018,7.764,8.118,8.8],
    'confidence' : [-0.182,0.964,1.564,2.545,3.645,4.5],
    'random' : [-5.755,-4.036,-1.573,1.182,3.618,5]
}

cifar = {
    'WEDE' : [2,2.7,3.28,3.88,3.98,4.26],
    'confidence' : [-1.64,-1.3,-0.56,-0.48,0.46,0.9],
    'random' : [-3.7,-0.64,-0.2,0.36,1.34,1.74]
}

marker = {
    'WEDE': 's',
    'confidence': 'o',
    'random': 'd'
}

fig, ax = plt.subplots(2,2, figsize=(10,5))
# fig, ax = plt.subplots(1,2, figsize=(10,3))

n_data = [600, 900, 1200, 1500, 1800, 2100]
ax = ax.flatten()

for key,val in cifar.items():
    ax[0].plot(n_data, val, marker = marker[key], markersize=10, label=key)
ax[0].set_title('Cifar-4-Class')

for key,val in core_object.items():
    ax[1].plot(n_data, val, marker = marker[key], markersize=10)
ax[1].set_title('Core-Object')

for key,val in core_session.items():
    ax[2].plot(n_data, val, marker = marker[key], markersize=10)
ax[2].set_title('Core-Session')

fig.delaxes(ax[3])
fig.legend(loc='lower right', fontsize=15)
# fig.legend(loc='lower right', fontsize=12)


fig.supxlabel('Acquisition Budget', fontsize=12)
fig.supylabel('Accuracy Improvement (%)', fontsize=12)
fig.tight_layout()
fig.show()

# %% [markdown]
# # proxy, ensemble

# %%
core_session= {
    'U-WFS + WTA':  [3.964,6.255,7.318,8.027,8.773,9.618],
    'U-WFSD + WTA': [4.191,6.364,7.509,8.227,8.855,9.464],
    'U-WFS + AE':  [4.809,7.236,8.336,9.264,10.127,10.927],
    'U-WFSD + AE':  [4.991,7.145,8.545,9.345,10.082,10.782],
}

core_object= {
    'U-WFS + WTA':  [2.273,3.691,4.709,5.127,5.373,6.109],
    'U-WFSD + WTA': [2.964,4.045,4.473,5.3,5.636,5.918],
    'U-WFS + AE':  [3.555,4.882,5.873,6.482,6.673,7.364],
    'U-WFSD + AE':  [4,5.273,5.673,6.555,6.818,7.218],
}

cifar = {
    'U-WFS + WTA':  [0.02,1.68,1.86,2.38,2.76,3.84],
    'U-WFSD + WTA': [-0.34,1.66,1.54,1.72,3.28,3.44],
    'U-WFS + AE':  [2.04,3.44,3.06,3.42,3.1,4.2],
    'U-WFSD + AE':  [1.66,3.18,3.1,3.06,3.06,3.8],
}

marker = {
    'U-WFS + WTA':  'd',
    'U-WFSD + WTA': 's',
    'U-WFS + AE':  'o',
    'U-WFSD + AE':  '^',
}

fig, ax = plt.subplots(2,2, figsize=(10, 5))
# fig, ax = plt.subplots(1,2, figsize=(10,3))

n_data = [600, 900, 1200, 1500, 1800, 2100]
ax = ax.flatten()

for key,val in cifar.items():
    ax[0].plot(n_data, val, marker = marker[key], markersize=10, label = key)
ax[0].set_title('Cifar-4-Class')

for key,val in core_object.items():
    ax[1].plot(n_data, val, marker = marker[key], markersize=10)
ax[1].set_title('Core-Object')

for key,val in core_session.items():
    ax[2].plot(n_data, val, marker = marker[key], markersize=10)
ax[2].set_title('Core-Session')

fig.delaxes(ax[3])
fig.legend(loc='lower right', fontsize=15)

fig.supxlabel('Acquisition Budget', fontsize=12)
fig.supylabel('Accuracy Improvement (%)', fontsize=12)
fig.tight_layout()
fig.show()

# %% [markdown]
# # complexity

# %%
core_object= {
    'SqueezeNet':  [11.491,10.209,8.591,6.582,4.5,3.8],
    'Resnet18': [17.382,15.827,11.9,10.936,7.545,5.6],
    'Resnet34':  [17.991,15.591,12.609,14,12.863,10.536],
}

cifar = {
    'SVM': [2,2.6,0.5,0.5,-0.2,0],
    'SqueezeNet':  [3.8,3.4,2,0.7,6.9,2.1],
    'Resnet18': [5.4,1.5,3,2.5,4.6,0.93],
}

marker = {
    'SVM': 'o',
    'SqueezeNet': '^',
    'Resnet18': 's',
    'Resnet34': 'd'
}

fig, ax = plt.subplots(1,2, figsize=(10,3))

n_data = [600, 900, 1200, 1500, 1800, 2100]
ax = ax.flatten()
for key,val in core_object.items():
    ax[0].plot(n_data, val, marker = marker[key], label=key, markersize=10)
ax[0].set_title('Core-Object')
ax[0].legend()
for key,val in cifar.items():
    ax[1].plot(n_data, val, marker = marker[key], label=key, markersize=10)
ax[1].set_title('Cifar-2-Class')
ax[1].legend()

# fig.legend(bbox_to_anchor=(1, 1), loc='upper left')
fig.supxlabel('Acquisition Budget',fontsize=12)
fig.supylabel('WEDE over Random (%)',fontsize=12)
fig.tight_layout()
fig.show()

# %% [markdown]
# # shift degree

# %%
core = {
    '2 sessions':  [5.055,7.61,8.818,8.218,6.864,5.91],
    '3 sessions': [11.509,10.654,9.072,7.209,5.737,4.991],
    '5 sessions':  [9.509,6.682,4.636,3.073,1.655,1.336],
}

cifar = {
    '1 subclasses': [2,0.8,-1.7,-1.2,-2.7,-2.6],
    '2 subclasses': [-0.5,-0.9,-3,-3,-3.1,-3.6],
    '3 subclasses': [-3.6,-3.2,-6.6,-5.7,-5.9,-5.6]
}

marker = {
    '2 sessions':  'o',
    '3 sessions': 's',
    '5 sessions':  'd',
    '1 subclasses': 'o',
    '2 subclasses': 's',
    '3 subclasses': 'd'
}

fig, ax = plt.subplots(1,2, figsize=(10,3))

n_data = [600, 900, 1200, 1500, 1800, 2100]
ax = ax.flatten()
for key,val in core.items():
    ax[0].plot(n_data, val, marker = marker[key], label = key, markersize=10)
ax[0].set_title('Core-Session')
ax[0].legend(loc='upper right', fontsize=11)

for key,val in cifar.items():
    ax[1].plot(n_data, val, label = key, marker = marker[key], markersize=10)
ax[1].set_title('Cifar-2-Class')
ax[1].legend(loc='upper right', fontsize=11)

fig.supxlabel('Acquisition Budget', fontsize=12)
fig.supylabel('WEDE over Random (%)', fontsize=12)
fig.tight_layout()
fig.show()

# %% [markdown]
# # SVM vs Log

# %% [markdown]
# ## error in new data

# %%
core_session= {
    'SVM': [86.283,83.722,80.583,76.727,72.256,67.443],
    'Logistic Regression': [87.35, 83.356, 78.917, 74.32, 69.606, 65.681],
}

core_object= {
    'SVM': [72.467,68.567,64.425,59.34,55.978,52.971],
    'Logistic Regression': [74.35, 68.567, 63.567, 58.94, 55.6, 52.748],
}

cifar = {
    'SVM': [74.4,73.289,71.342,69.8,67.85,66.224],
    'Logistic Regression': [74.933, 73.367, 71.383, 69.333, 67.45, 66.052],
}

marker = {
    'Logistic Regression': 'd',
    'SVM':  'o',
}

fig, ax = plt.subplots(2,2, figsize=(10, 5))
# fig, ax = plt.subplots(1,2, figsize=(10, 3))

n_data = [600, 900, 1200, 1500, 1800, 2100]
ax = ax.flatten()

for key,val in cifar.items():
    ax[0].plot(n_data, val, marker = marker[key], markersize=10, label=key)
ax[0].set_title('Cifar-4-Class')

for key,val in core_object.items():
    ax[1].plot(n_data, val, marker = marker[key], markersize=10)
ax[1].set_title('Core-Object')

for key,val in core_session.items():
    ax[2].plot(n_data, val, marker = marker[key], markersize=10)
ax[2].set_title('Core-Session')
fig.delaxes(ax[3])

fig.legend(loc='lower right', fontsize=15)

fig.supxlabel('Acquisition Budget', fontsize=12)
fig.supylabel('Percentage of Misclassified Acquired Data(%)', fontsize=12)
fig.tight_layout()
fig.show()

# %% [markdown]
# ## acc

# %%
core_session= {
    'SVM': [4.991,7.145,8.545,9.345,10.082,10.782],
    'Logistic Regression': [4.973, 7.282, 9.082, 9.955, 10.973, 11.745],
}

core_object= {
    'SVM': [5.736,6.173,7.018,7.764,8.118,8.8],
    'Logistic Regression': [4.873, 6.245, 6.982, 8.0, 8.673, 8.791],
}

cifar = {
    'SVM': [2,2.7,3.28,3.88,3.98,4.26],
    'Logistic Regression': [2.3, 3.48, 4.38, 3.62, 4.38, 4.04],
}

marker = {
    'Logistic Regression': 'd',
    'SVM':  'o',
}

fig, ax = plt.subplots(2,2, figsize=(10, 5))
# fig, ax = plt.subplots(1,2, figsize=(10, 3))

n_data = [600, 900, 1200, 1500, 1800, 2100]
ax = ax.flatten()

for key,val in cifar.items():
    ax[0].plot(n_data, val, marker = marker[key], markersize=10, label=key)
ax[0].set_title('Cifar-4-Class')

for key,val in core_object.items():
    ax[1].plot(n_data, val, marker = marker[key], markersize=10)
ax[1].set_title('Core-Object')

for key,val in core_session.items():
    ax[2].plot(n_data, val, marker = marker[key], markersize=10)
ax[2].set_title('Core-Session')
fig.delaxes(ax[3])

fig.legend(loc='lower right', fontsize=15)

fig.supxlabel('Acquisition Budget', fontsize=12)
fig.supylabel('Accuracy Improvement(%)', fontsize=12)
fig.tight_layout()
fig.show()

# %% [markdown]
# # greedy vs seq

# %% [markdown]
# ## total acc

# %%
core_session= {
    'one-shot + AE': [5.236,7.291,8.427,9.518,10.064,10.464],
    'sequential + AE': [4.991,7.145,8.545,9.345,10.082,10.782],
    'one-shot + WTA': [4.491,6.582,7.409,8.318,8.791,8.955],
    'sequential + WTA':[-5.109,-0.436,0.745,3.318,5.336,7.991],
}

core_object= {
    'one-shot + AE': [3.555,4.882,5.873,6.482,6.673,7.364],
    'sequential + AE':  [5.736,6.173,7.018,7.764,8.118,8.8],
    'one-shot + WTA': [2.273,3.691,4.709,5.127,5.373,6.109],
    'sequential + WTA': [-7.845,-4.291,-0.745,2.2,3.691,5.618],
}

cifar = {
    'one-shot + AE': [2.04,3.44,3.06,3.42,3.1,4.2],
    'sequential + AE':  [2,2.7,3.28,3.88,3.98,4.26],
    'one-shot + WTA': [0.02,1.68,1.86,2.38,2.76,3.84],
    'sequential + WTA': [-7.9,-7,-5.9,-3.58,-2.7,-0.78],
}
marker = {
    'one-shot + WTA':  'd',
    'sequential + WTA': 's',
    'one-shot + AE':  'o',
    'sequential + AE':  '^',
}

fig, ax = plt.subplots(2,2, figsize=(10, 5))
# fig, ax = plt.subplots(1,2, figsize=(10, 3))

n_data = [600, 900, 1200, 1500, 1800, 2100]
ax = ax.flatten()

for key,val in cifar.items():
    ax[0].plot(n_data, val, marker = marker[key], markersize=10, label=key)
ax[0].set_title('Cifar-4-Class')

for key,val in core_object.items():
    ax[1].plot(n_data, val, marker = marker[key], markersize=10)
ax[1].set_title('Core-Object')

for key,val in core_session.items():
    ax[2].plot(n_data, val, marker = marker[key], markersize=10)
ax[2].set_title('Core-Session')
fig.delaxes(ax[3])

fig.legend(loc='lower right', fontsize=15)

fig.supxlabel('Acquisition Budget', fontsize=12)
fig.supylabel('Accuracy Improvement (%)', fontsize=12)
fig.tight_layout()
fig.show()

# %% [markdown]
# ## ae

# %%
core_session= {
    'one-shot': [5.236,7.291,8.427,9.518,10.064,10.464],
    'sequential': [4.991,7.145,8.545,9.345,10.082,10.782],
}

core_object= {
    'one-shot': [3.555,4.882,5.873,6.482,6.673,7.364],
    'sequential':  [5.736,6.173,7.018,7.764,8.118,8.8],
}

cifar = {
    'one-shot': [2.04,3.44,3.06,3.42,3.1,4.2],
    'sequential':  [2,2.7,3.28,3.88,3.98,4.26],
}

marker = {
    'one-shot': 'd',
    'sequential':  'o',
}

fig, ax = plt.subplots(2,2, figsize=(10, 5))
# fig, ax = plt.subplots(1,2, figsize=(10, 3))

n_data = [600, 900, 1200, 1500, 1800, 2100]
ax = ax.flatten()

for key,val in cifar.items():
    ax[0].plot(n_data, val, marker = marker[key], markersize=10, label=key)
ax[0].set_title('Cifar-4-Class')

for key,val in core_object.items():
    ax[1].plot(n_data, val, marker = marker[key], markersize=10)
ax[1].set_title('Core-Object')

for key,val in core_session.items():
    ax[2].plot(n_data, val, marker = marker[key], markersize=10)
ax[2].set_title('Core-Session')
fig.delaxes(ax[3])

fig.legend(loc='lower right', fontsize=15)

fig.supxlabel('Acquisition Budget', fontsize=12)
fig.supylabel('Accuracy Improvement (%)', fontsize=12)
fig.tight_layout()
fig.show()

# %% [markdown]
# ## error in new data

# %%
core_session= {
    'sequential': [86.283,83.722,80.583,76.727,72.256,67.443],
    'one-shot':  [81.667,78.433,74.233,70.28,66.6,63.21],
}

core_object= {
    'sequential': [72.467,68.567,64.425,59.34,55.978,52.971],
    'one-shot':  [60.083,56.567,53.375,51.233,49.272,47.219],
}

cifar = {
    'sequential': [74.4,73.289,71.342,69.8,67.85,66.224],
    'one-shot':  [71.333,69.867,68.85,67.373,66.25,64.833],
}

marker = {
    'one-shot': 'd',
    'sequential':  'o',
}

fig, ax = plt.subplots(2,2, figsize=(10, 5))
# fig, ax = plt.subplots(1,2, figsize=(10, 3))

n_data = [600, 900, 1200, 1500, 1800, 2100]
ax = ax.flatten()

for key,val in cifar.items():
    ax[0].plot(n_data, val, marker = marker[key], markersize=10, label = key)
ax[0].set_title('Cifar-4-Class')

for key,val in core_object.items():
    ax[1].plot(n_data, val, marker = marker[key], markersize=10)
ax[1].set_title('Core-Object')

for key,val in core_session.items():
    ax[3].plot(n_data, val, marker = marker[key], markersize=10)
ax[3].set_title('Core-Session')

fig.delaxes(ax[2])
fig.legend(loc='lower left', fontsize=15)
# fig.legend(loc='upper right', fontsize=15)


fig.supxlabel('Acquisition Budget', fontsize=12)
fig.supylabel('Percentage of Misclassified Acquired Data (%)', fontsize=10)
fig.tight_layout()
fig.show()

# %% [markdown]
# ## precision of errors

# %%
## Detector Accuracy
import numpy as np
core_object= {
    'sequential' : {
        600: [59.30518258899458, 72.36862707713384],
        900: [62.9207892931758, 72.6199536891142],
        1200: [64.59829576970324, 76.01097360806827],
        1500: [62.616149596730544, 73.57724304662958],
        1800: [63.242760517559574, 74.5142343000663],
        2100: [64.17308232436741, 70.70455585810235]
    },
    'one-shot': 39.50,
}

cifar = {
    'sequential' : {
        600: [65.62133446889126, 67.71136445653764],
        900: [66.97647454441069, 69.41342617234275],
        1200: [67.35281791202877, 70.41198657285494],
        1500: [67.71386528838505, 69.66339616921618],
        1800: [68.08334952055833, 71.2536832703406],
        2100: [68.30654318586338, 72.22728259058925]
    },
    'one-shot': 59.30
}

core_session= {
    'sequential' : {
        600: [75.1342546402938, 77.27362671029539],
        900: [75.76419807842225, 77.43702587703876],
        1200: [76.19420965271783, 77.22114608227447],
        1500: [76.35100688916428, 76.77953952666124],
        1800: [75.82859466305774, 78.53809006604692],
        2100: [76.43229184667682, 79.01048182652026]
    },
    'one-shot': 51.975,
}

labels = ['one-shot', 'sequential: after 1st round', 'sequential: after 2nd round']
pattern = {'one-shot': '', 'sequential: after 1st round': '/', 'sequential: after 2nd round': 'o'}
n_data = [600, 900, 1200, 1500, 1800, 2100]


fig, ax = plt.subplots(2,2, figsize=(10, 5))
ax = ax.flatten()
width = 0.25  # the width of the bars
x = np.arange(6)

vis = {'one-shot': [], 'sequential: after 1st round': [], 'sequential: after 2nd round': []}
multiplier = 0

for key, values in cifar['sequential'].items():
    vis['one-shot'].append(cifar['one-shot'])
    vis['sequential: after 1st round'].append(values[0])
    vis['sequential: after 2nd round'].append(values[1])

for key, values in vis.items():
    offset = width * multiplier
    rects = ax[0].bar(x + offset, values, width, label=key,fill=False, hatch=pattern[key])
    # ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax[0].set_xticks(x + width, n_data)
# ax[0].legend(loc='upper left', ncols=3)
ax[0].set_ylim(0, 100)
ax[0].set_title('Cifar-4-Class')

vis = {'one-shot': [], 'sequential: after 1st round': [], 'sequential: after 2nd round': []}
multiplier = 0

for key, values in core_object['sequential'].items():
    vis['one-shot'].append(core_object['one-shot'])
    vis['sequential: after 1st round'].append(values[0])
    vis['sequential: after 2nd round'].append(values[1])
for key, values in vis.items():
    offset = width * multiplier
    rects = ax[1].bar(x + offset, values, width, fill=False, hatch=pattern[key])
    # ax.bar_label(rects, padding=3)
    multiplier += 1

ax[1].set_xticks(x + width, n_data)
ax[1].set_ylim(0, 100)
ax[1].set_title('Core-Object')

vis = {'one-shot': [], 'sequential: after 1st round': [], 'sequential: after 2nd round': []}
multiplier = 0

for key, values in core_session['sequential'].items():
    vis['one-shot'].append(core_session['one-shot'])
    vis['sequential: after 1st round'].append(values[0])
    vis['sequential: after 2nd round'].append(values[1])
for key, values in vis.items():
    offset = width * multiplier
    rects = ax[2].bar(x + offset, values, width, fill=False, hatch=pattern[key])
    # ax.bar_label(rects, padding=3)
    multiplier += 1
ax[2].set_xticks(x + width, n_data)
ax[2].set_ylim(0, 100)
ax[2].set_title('Core-Session')

fig.delaxes(ax[3])

fig.legend(loc='lower right', fontsize=15)
fig.supxlabel('Acquisition Budget', fontsize=12)
fig.supylabel('Weakness Detection Accuracy(%)', fontsize=12)
fig.tight_layout()
fig.show()

plt.show()

# %% [markdown]
# ## wede train

# %%
## Detector Accuracy
import numpy as np
core_object= {
    'sequential' : {
        600: [39.0235294117647, 49.756521739130434],
        900:[ 41.910000000000004, 52.03448275862068], 
        1200: [43.29565217391304, 52.02857142857143],
        1500: [44.115384615384606, 50.1219512195122],
        1800: [44.58620689655173, 48.72340425531915],
        2100: [44.88125, 47.162264150943386]
    },
    'one-shot': 25,
}

cifar = {
    'sequential' : {
        600: [57.1625, 62.14545454545455],
        900: [59.32631578947369, 64.05714285714285],
        1200: [60.47272727272726, 64.31176470588235],
        1500: [61.424, 64.21],
        1800: [61.857142857142854, 63.413043478260875],
        2100: [62.283870967741926, 62.611538461538466],
    },
    'one-shot': 47.44
}

core_session= {
    'sequential' : {
        600: [46.68235294117646, 57.26086956521739],
        900: [51.64, 61.675862068965515],
        1200: [54.85217391304347, 63.302857142857135],
        1500: [57.13846153846155, 63.00975609756098],
        1800: [58.39310344827586, 61.336170212765964],
        2100: [58.93125, 58.758490566037736]
    },
    'one-shot': 25.6,
}

labels = ['one-shot', 'sequential: after 1st round', 'sequential: after 2nd round']
pattern = {'one-shot': '', 'sequential: after 1st round': '/', 'sequential: after 2nd round': 'o'}
n_data = [600, 900, 1200, 1500, 1800, 2100]


fig, ax = plt.subplots(2,2, figsize=(10, 5))
ax = ax.flatten()
width = 0.25  # the width of the bars
x = np.arange(6)

vis = {'one-shot': [], 'sequential: after 1st round': [], 'sequential: after 2nd round': []}
multiplier = 0

for key, values in cifar['sequential'].items():
    vis['one-shot'].append(cifar['one-shot'])
    vis['sequential: after 1st round'].append(values[0])
    vis['sequential: after 2nd round'].append(values[1])

for key, values in vis.items():
    offset = width * multiplier
    rects = ax[0].bar(x + offset, values, width, label=key,fill=False, hatch=pattern[key])
    # ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax[0].set_xticks(x + width, n_data)
# ax[0].legend(loc='upper left', ncols=3)
ax[0].set_ylim(0, 100)
ax[0].set_title('Cifar-4-Class')

vis = {'one-shot': [], 'sequential: after 1st round': [], 'sequential: after 2nd round': []}
multiplier = 0

for key, values in core_object['sequential'].items():
    vis['one-shot'].append(core_object['one-shot'])
    vis['sequential: after 1st round'].append(values[0])
    vis['sequential: after 2nd round'].append(values[1])
for key, values in vis.items():
    offset = width * multiplier
    rects = ax[1].bar(x + offset, values, width, fill=False, hatch=pattern[key])
    # ax.bar_label(rects, padding=3)
    multiplier += 1

ax[1].set_xticks(x + width, n_data)
ax[1].set_ylim(0, 100)
ax[1].set_title('Core-Object')

vis = {'one-shot': [], 'sequential: after 1st round': [], 'sequential: after 2nd round': []}
multiplier = 0

for key, values in core_session['sequential'].items():
    vis['one-shot'].append(core_session['one-shot'])
    vis['sequential: after 1st round'].append(values[0])
    vis['sequential: after 2nd round'].append(values[1])
for key, values in vis.items():
    offset = width * multiplier
    rects = ax[2].bar(x + offset, values, width, fill=False, hatch=pattern[key])
    # ax.bar_label(rects, padding=3)
    multiplier += 1
ax[2].set_xticks(x + width, n_data)
ax[2].set_ylim(0, 100)
ax[2].set_title('Core-Session')

fig.delaxes(ax[3])

fig.legend(loc='lower right', fontsize=15)
fig.supxlabel('Acquisition Budget', fontsize=12)
fig.supylabel('WeDe Training Data from Cw(%)', fontsize=12)
fig.tight_layout()
fig.show()

plt.show()

# %% [markdown]
# ## recall

# %%
## Detector Accuracy
import numpy as np

one_shot = {
    'Cifar-4-Class': 62.12,
    'Core-Object': 63.765,
    'Core-Session': 71.24, 
}

sequential = {
    'Cifar-4-Class': 60.6,
    'Core-Object': 63.9,
    'Core-Session': 69,
}
width = 0.3  # the width of the bars
x = np.arange(3)
offset = 0
bar = plt.bar(x + offset, list(one_shot.values()), width, label='one-shot',fill=False, hatch='')
plt.bar_label(bar, fontsize=12)
offset = 1 * width
bar = plt.bar(x + offset, list(sequential.values()), width, label='sequential',fill=False, hatch='/')
plt.bar_label(bar, fontsize=12)

plt.legend( fontsize=15)
plt.xlabel('Task', fontsize=15)
plt.xticks(x + width, list(one_shot.keys()))
plt.ylim(0, 100)
plt.ylabel('WeDe Average Recall(%)', fontsize=15)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## error in test data

# %%
## Detector Accuracy
import numpy as np

one_shot = {
    'Cifar-4-Class': 61.21,
    'Core-Object': 48.554,
    'Core-Session': 66.143,
}

sequential = {
    'Cifar-4-Class': 54,
    'Core-Object': 38,
    'Core-Session': 45.23,
}
width = 0.3  # the width of the bars
x = np.arange(3)
offset = 0
plt.bar(x + offset, list(one_shot.values()), width, label='one-shot',fill=False, hatch='')
offset = 1 * width
plt.bar(x + offset, list(sequential.values()), width, label='sequential',fill=False, hatch='/')

plt.legend( fontsize=15)
plt.xlabel('Task', fontsize=15)
plt.xticks(x + width, list(one_shot.keys()))
plt.ylim(0, 100)
plt.ylabel('Percentage of Misclassified Test Data (%)', fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## unweighted

# %%
marker = {
    'one-shot': 'd',
    'sequential':  'o',
}

fig, ax = plt.subplots(2,2, figsize=(10, 5))
# fig, ax = plt.subplots(1,2, figsize=(10, 3))

n_data = [600, 900, 1200, 1500, 1800, 2100]
ax = ax.flatten()

for key,val in cifar.items():
    ax[0].plot(n_data, val, marker = marker[key], markersize=10, label=key)
ax[0].set_title('Cifar-4-Class')

for key,val in core_object.items():
    ax[1].plot(n_data, val, marker = marker[key], markersize=10)
ax[1].set_title('Core-Object')

for key,val in core_session.items():
    ax[2].plot(n_data, val, marker = marker[key], markersize=10)
ax[2].set_title('Core-Session')
fig.delaxes(ax[3])

fig.legend(loc='lower right', fontsize=15)

fig.supxlabel('Acquisition Budget', fontsize=12)
fig.supylabel('Accuracy Improvement (%)', fontsize=12)
fig.tight_layout()
fig.show()

# %% [markdown]
# # dstr

# %%
# intersection= {
#     'WEDE & unfiltered Data Pool': [5.367,10.667,11.1,12.3],
#     'random & unfiltered Data Pool':  [2.7,6.033,9.3,9.5],
#     'WEDE & filtered Data Pool': [7.8,11.767,12.767,13.933],
#     'random & filtered Data Pool':  [9.167,12.4,12.767,13.567],
# }

inclusion= {
    'WEDE & unfiltered Data Pool': [9.8,10.467,11.133,11.667],
    'random & unfiltered Data Pool':  [2.267,5.6,8.867,9.067],
    'WEDE & filtered Data Pool': [9.833,11.633,12.867,13.133],
    'random & filtered Data Pool':  [8.833,11.667,12.8,13.667],
}

marker = {
    'WEDE & unfiltered Data Pool': 'o',
    'random & unfiltered Data Pool':  'd',
    'WEDE & filtered Data Pool': 's',
    'random & filtered Data Pool':  '^',
}
n_data = [100, 200, 300, 400]
plt.figure(figsize=(6,3))
for key,val in inclusion.items():
    plt.plot(n_data, val, marker = marker[key], markersize=8, label=key)
plt.xlabel('Acquisition Budget', fontsize=12)
plt.ylabel('Accuracy Improvement (%)', fontsize=12)
plt.tight_layout()
plt.legend()
plt.show()
# fig, ax = plt.subplots(1, 1, figsize=(5,3))
# n_data = [100, 200, 300, 400]
# ax = ax.flatten()
# for key,val in intersection.items():
#     ax[0].plot(n_data, val, marker = marker[key], label = key, markersize=8)
# ax[0].set_title('Intersection')

# for key,val in inclusion.items():
#     ax[1].plot(n_data, val, marker = marker[key], markersize=8)
# ax[1].set_title('Inclusion')

# fig.legend(loc='lower right', fontsize=11)
# fig.supxlabel('Acquisition Budget', fontsize=12)
# fig.supylabel('Accuracy Improvement (%)', fontsize=12)
# fig.tight_layout()
# fig.show()
